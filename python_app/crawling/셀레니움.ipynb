# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from bs4 import BeautifulSoup
options = Options()
options.headless = True
browser = webdriver.Chrome(executable_path="./chromedriver.exe", options=options)
browser.get("https://datalab.naver.com/shoppingInsight/sCategory.naver")

time.sleep(3)
tag_names = browser.find_element_by_css_selector(".rank_top1000_list").find_elements_by_tag_name("li")
for tag in tag_names:
    print(tag.text.split("\n"))
# Out:
# ['1', '원피스']
# ['2', '리버클래시']
# ['3', '트위드자켓']
# ['4', '나이키바람막이']
# ['5', '트렌치코트']
# ['6', '블라우스']
# ['7', '바람막이']
# ['8', '여성트렌치코트']
# ['9', '잠옷']
# ['10', '롱원피스']
# ['11', '라쉬반']
# ['12', '후드집업']
# ['13', '맨투맨']
# ['14', '쥬시쥬디']
# ['15', '써스데이아일랜드원피스']
# ['16', '가디건']
# ['17', '나이키맨투맨']
# ['18', '여성자켓']
# ['19', '후드티']
# ['20', '남자트렌치코트']

# %%
browser.get("https://lib.kookmin.ac.kr/#/total-search?keyword=%EC%9E%90%EC%A1%B4%EA%B0%90%20%EC%88%98%EC%97%85")

# %%
browser.
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="1ebb1736db4ed28c9d05b60a9e9c1fc0")>

# %%
 res = browser.page_source

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(res, 'html.parser')

# %%
soup
# Out:
# <html class="k-webkit k-webkit80" lang="ko"><!--<!(endif)--><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
# <title>국민대학교 성곡도서관</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="./assets/css/ui.css" rel="stylesheet"/>
# <link href="./assets/images/km/favicon.ico" rel="shortcut icon"/>
# <link href="./assets/css/main.css?sv=2020.3.23.16" rel="stylesheet"/>
# <script async="" src="//www.google-analytics.com/analytics.js"></script><script src="./assets/files/jquery-1.11.3.min.js" type="text/javascript"></script>
# <script src="./assets/files/nppfs-1.9.0.js" type="text/javascript"></script>
# ...

# %%
res4 = soup.find('div', {'ui-view':'pyxis-total-result'})

# %%
res4
# Out:
# <div ui-view="pyxis-total-result"><div class="ikc-search-result-listup" ng-show="mashupResultPyxisTotalCount &gt; 0"><p><strong>소장자료</strong>   <strong class="ikc-search-result-count">10</strong></p></div><!-- --><div class="ikc-search-result" ng-if="mashupResultPyxisTotalCount"><!-- --><div class="ikc-search-item" ng-repeat="data in mashupResultPyxis"><div class="ikc-item-aside"><div class="ikc-item-bibliotype"><ik-book-thumb bid="data.id" class="ikc-item-bookcover" isbn="data.isbn" thumbnail="data.thumbnailUrl" title="자존감 수업 :하루에 하나, 나를 사랑하게 되는 자존감 회복 훈련"><div class="ikc-bookcover">
# <img alt="자존감 수업 :하루에 하나, 나를 사랑하게 되는 자존감 회복 훈련" class="ikc-item-bookcover" ng-src="http://image.aladin.co.kr/product/8679/31/cover/k372535696_1.jpg" onerror="this.src='/assets/images/km/common/default-item-img.png'" src="http://image.aladin.co.kr/product/8679/31/cover/k372535696_1.jpg"/>
# ...

# %%
res5 = res4.find_all('div', {'class': 'ikc-search-item'})

# %%
len(res5)
# Out:
# 5

# %%
res6 = res5[0].find('a')

# %%
res6
# Out:
# <a class="ikc-item-title" href="#/search/detail/3263775" ng-href="#/search/detail/3263775"><span ng-bind-html="data.titleStatement | IKGHighlight:searchKeywords">자존감 수업 :하루에 하나, 나를 사랑하게 되는 자존감 회복 훈련</span></a>

# %%
res6.text
# Out:
# '자존감 수업 :하루에 하나, 나를 사랑하게 되는 자존감 회복 훈련'
